# %%
"""My code has a bug in lines 262 and 303 that includes a +1 
because it was the only way I could get the print statement 
to say how many attempts player had left. Otherwise, the print statement 
would show an incorrect number of attempts left for player (From first resubmit).

Resubmit II comments: I fixed the error mentioned above. But, I get a new error.
When player "wins game," it should jump to trivia question after user hits Enter.
Instead, user has to hit Enter twice to get to trivia question.

Also, I added all prompts I could find. I only have two variatons of it,
I think. If that's not the case, I could not identify where I'm missing more prompts.
Can you, please, let me know where I'm missing any more...an example, not all errors.
Thanks for the chance to resubmit this assignment...twice!"""

#importing random to use below
import random

#Getting player's name and capitalizing first letter
name = input(prompt = "What's your name?\n")
capitalize_name = name.capitalize()

print("""\nAre you ready for some football? 

You’re the coach for the San Francisco 49ERS and have taken your team 
all the way to the Super Bowl! It’s been a tough game, though. 
It’s the 4th quarter with only 54 seconds to go and the 
Pittsburgh Steelers just scored to take the lead. You’re down 28-33.
You need to take your team 75 yards to score a touchdown and win the game. 
To make it just a little harder, you’re out of time outs. 
Have fun and try to make the right calls to a Super Bowl ring.\n""")

#Defining the start of the game
def greeting_1():
    print(f"\nAre you ready to play, Coach {capitalize_name}?\n")
    input(prompt = '<Press any key to continue>\n')
    

greeting_1() # This starts the game
    
#Player selects first play to run from 25th yard at 54 seconds
def play_1():
    print("What's your first play call, coach?\n")
    print("Press 1 for a deep center pass.")
    print("Press 2 for a quaterback draw.")
    print("Press 3 for a screen right to halfback")
    print("Press 4 for a curl left to wide receiver")
    
    choice = input(prompt = "> ")
    
    #Setting up conditional statements
    #Possible options in case user does not pick a digit to answer
    if choice == '4' or 'four' in choice or 'curl'in choice or 'left' in choice\
        or 'wide' in choice or 'receiver' in choice:
        print("\nGreat call, coach. Wisely, your WR runs out of bounds to stop the clock.\n")
        play_2()
                
        choice = input(prompt = "> ")
        
    #Choices below will end game and jump down to trivia question and end of game    
    elif choice == '1' or 'one' in choice or 'deep' in choice or 'center' in choice\
            or 'pass' in choice:
            print("Pass is picked off.\n")
            input(prompt = '<Press any key to continue>\n')         
            
            fail()
            
    elif choice == '2' or 'two' in choice or 'quater' in choice or 'draw' in choice:
            print("QB drops the ball and defense recovers.\n")
            input(prompt = '<Press any key to continue>\n')
            
            fail()
            
    elif choice == '3' or 'three' in choice or 'screen' in choice or\
            'right' in choice or 'half' in choice or 'back' in choice:
            print("HB takes ball downfield and loses it. Defense recovers.\n")
            input(prompt = '<Press any key to continue>\n')
              
            fail()
    
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        play_1()

        
#Play 2 starts at the 43 yard line with 42 seconds left on the clock
#Player can pick second play
def play_2():
    print("You're on the Steelers' 43 yard line with 42 secs left on the clock.\n")
    input(prompt = '<Press any key to continue>\n')
    print("What would you like to do for this play, coach?\n")
            
    print("Press 1 for option read pass.")
    print("Press 2 for a halfback draw.")
    print("Press 3 for a field goal")
    print("Press 4 for a hail mary to endzone")
    
    choice = input(prompt = "> ")
    
    if choice == '1' or 'one' in choice or 'option' in choice or 'read' in choice\
        or 'pass' in choice:
        print("\nYour're on a roll, coach. TE catches pass for 17 yards.\n")
        
        print("Time's running out. You're on the Steelers' 26 yd line with 25 sec left.\n")    
        play_3()
    
    #Choices below will end game and jump down to trivia question and end of game    
    elif choice == '4' or 'four' in choice or 'hail' in choice or 'mary' in choice\
            or 'end' in choice or 'zone' in choice:
            print("Pass is picked off in the endzone.")
            
            fail()
            
    elif choice =='2' or 'two' in choice or 'half' in choice or 'back' in choice\
            or 'draw' in choice:
            print("Your HB fumbled the ball and defense recovers!")
            input(prompt = '<Press any key to continue>\n')
            
            fail()
            
    elif choice =='3' or 'three' in choice or 'field' in choice or 'goal' in choice:
            print("FG is missed!")
            input(prompt = '<Press any key to continue>\n')
            
            fail()    
      
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        play_2()
        
#Play 3 starts at the 26 yard line with 25 seconds left on the clock
#Player can pick third play
def play_3():
    input(prompt = '<Press any key to continue>\n')
    print("What's the next call? You're making great desicions, coach?\n")
            
    print("Press 1 for attempt a field goal.")
    print("Press 2 for a flea flicker to endzone.")
    print("Press 3 for a quarterback sneak")
    print("Press 4 for a screen pass to right")
    
    choice = input(prompt = "> ")
    
    if choice == '4' or 'four' in choice or 'screen' in choice or 'pass' in choice\
        or 'right' in choice:
        print("\nMoving the ball, coach. 7 seconds left on the clock.\n")
         
        play_4()
        
    #Choices below will end game and jump down to trivia question and end of game    
    elif choice == '1' or 'one' in choice or 'attempt' in choice or 'field' in choice\
            or 'goal' in choice:
            print("FG is good but you lost the game. That was a terrible call, coach.")
            
            fail()
            
    elif choice =='2' or 'two' in choice or 'flea' in choice or 'flicker' in choice\
            or 'end' in choice or 'zone' in choice:
            print("Ball is picked off!")
            input(prompt = '<Press any key to continue>\n')
            
            fail()
            
    elif choice =='3' or 'three' in choice or 'quater' in choice or 'back' in choice\
            or 'sneak' in choice:
            print("QB loses snap and defense recovers!")
            input(prompt = '<Press any key to continue>\n')
            
            fail()    
        
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        play_3()    


#Play 4 starts at the 12 yard line with 7 seconds left on the clock
#Player can pick fourth play
def play_4():
    print("Last play, coach?\n")
    input(prompt = '<Press any key to continue>\n')
    print("You're on the Steelers 12 yard line and 7 secs left on the clock.\n")
           
    print("Press 1 for the annexation of Puerto Rico.")
    print("Press 2 for a quaterback sneak.")
    print("Press 3 for a pass to back of end zone")
    print("Press 4 for a wide receiver reverse")
       
    choice = input(prompt = "> ")
    
       
    if choice == '3' or 'three' in choice or 'pass' in choice or 'back' in choice\
        or 'end' in choice or 'zone' in choice:
        random_print = random.randint(1,20)
        
        if random_print > 10:
            print("""\n  
   _______               _         _                       _ _ _ 
 |__   __|             | |       | |                     | | | |
    | | ___  _   _  ___| |__   __| | _____      ___ __   | | | |
    | |/ _ \| | | |/ __| '_ \ / _` |/ _ \ \ /\ / / '_ \  | | | |
    | | (_) | |_| | (__| | | | (_| | (_) \ V  V /| | | | |_|_|_|
    |_|\___/ \__,_|\___|_| |_|\__,_|\___/ \_/\_/ |_| |_| (_|_|_)
    \n""")
            end_game()
        
                    
        elif random_print < 10:
            print("""\n
 __     __                    _         _ _ _ 
 \ \   / /                   (_)       | | | |
  \ \_/ /__  _   _  __      ___ _ __   | | | |
   \   / _ \| | | | \ \ /\ / / | '_ \  | | | |
    | | (_) | |_| |  \ V  V /| | | | | |_|_|_|
    |_|\___/ \__,_|   \_/\_/ |_|_| |_| (_|_|_)
                                               \n""")
            end_game()
        
                        
        else:
            print("""\n
 __          __           _                        _ _ _ 
 \ \        / /          | |                      | | | |
  \ \  /\  / /_ _ _   _  | |_ ___     __ _  ___   | | | |
   \ \/  \/ / _` | | | | | __/ _ \   / _` |/ _ \  | | | |
    \  /\  / (_| | |_| | | || (_) | | (_| | (_) | |_|_|_|
     \/  \/ \__,_|\__, |  \__\___/   \__, |\___/  (_|_|_)
                   __/ |              __/ |              
                  |___/              |___/    
            \n""")
            end_game()
        
    #Choices below will end game and jump down to trivia question and end of game              
    elif choice == '1' or 'one' in choice or 'annexation' in choice\
            or 'uerto' in choice or 'ico' in choice:
            print("Great play but defense did not fall for it.\n")
            fail()
            
                       
    elif choice =='2' or 'two' in choice or 'quater' in choice or 'back' in choice\
            or 'sneak' in choice:
            print("Ball is dropped!")
            input(prompt = '<Press any key to continue>\n')
            
            fail()
            
    elif choice =='4' or 'four' in choice or 'wide' in choice or 'receiver' in choice:
            print("WR is tackled at the 1 yard line. So close!\n")
            input(prompt = '<Press any key to continue>\n')
            fail()
            
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        play_4() 

#Defining fail for when an incorrect play is chosen. 
def fail():
    print("Tough loss, Coach.\n")
    
def end_game ():
    print("You did it, Coach!!!\n")

play_1()
input(prompt = '< Press enter to continue to trivia. >\n')

#After game, trivia questions
#Generating random digit to determine final question
random = random.randint(1,2)

#If random integer is 1, use this question. 
if random == 1:
    print(f"""Now, can you guess how many Super Bowls the 49ERS have won in their franchise's history?\n
    --Use digits to guess.--""")

    # setting answer attempts to three
    ans_attempts = 3

    # exiting the loop after three attempts
    while ans_attempts > 0 :
        ans_guess = input(prompt = "How many do you think?.\n> ")

        if ans_guess == '5' or 'five' in ans_guess:
            print(f"""
            {'*'*20}
            \nWow! Alright, you really know your football.\n
Way to go, Coach. Congratulations!!!\n
            {'*'*20}""")
            input(prompt = '< Press enter to finish game. >\n')
            break

           
        # diminishing answer_attempts
        elif ans_guess != ans_attempts:
            ans_attempts -= 1
            
            #If user still has attempts left, printing message below        
            if ans_attempts > 0:
                print(f"""
            That is not the correct number of Super Bowls.
            You have {ans_attempts} attempt(s) remaining.\n""")
                
            elif ans_attempts == 0:
                print ("Sorry, the 49ERS have won 5 Super Bowls.")
                input(prompt = '< Press enter to finish game. >\n')
                break
                
            else:
                print("Something went wrong.")
  
        else:
            print("Something went wrong.")
            
elif random == 2:
    print("""Now, do you know what team has the most Super Bowl wins?\n""")
    print("49ERS")
    print("Steelers")
    print("Cowboys")
    print("Patriots")
    
    # setting answer attempts to three
    ans_attempts = 3

    # exiting the loop after three attempts
    while ans_attempts > 0 :
        ans_guess = input(prompt = "Who do you think?.\n> ")
        ans_guess = ans_guess.casefold()

        if ans_guess == 'steel' in ans_guess or 'patriot' in ans_guess or 'pats' in ans_guess:
            print(f"""
            {'*'*20}
            \nWow! Alright, you really know your football.\n
Did you get both teams?\n
The Steelers and the Patriots have 6 Super Bowls, each.
            {'*'*20}""")
            input(prompt = '< Press enter to end game. >\n')
            break

        # diminishing answer_attempts
        elif ans_guess != ans_attempts:
            ans_attempts -= 1
        
            if ans_attempts > 0:
                print(f"""
            That is not the right answer.
            You have {ans_attempts} attempt(s) remaining.\n""")
                       
            elif ans_attempts == 0:
                print ("Sorry, this was a trick questions. \
Both the Steelers and the Patriots have 6 Super Bowls, each.")
                input(prompt = '< Press enter to end game. >\n')
                break
            
            else: 
                print("Something went wrong.")
        
         
        else:
            print("Something went wrong.")
            
else:
    print("Something went wrong.")

print("Thanks for playing!")
# Out:
# What's your name?
# ale
#
# Are you ready for some football?
#
# You’re the coach for the San Francisco 49ERS and have taken your team
# all the way to the Super Bowl! It’s been a tough game, though.
# It’s the 4th quarter with only 54 seconds to go and the
# Pittsburgh Steelers just scored to take the lead. You’re down 28-33.
# You need to take your team 75 yards to score a touchdown and win the game.
# To make it just a little harder, you’re out of time outs.
# Have fun and try to make the right calls to a Super Bowl ring.
#
#
# Are you ready to play, Coach Ale?
#
# <Press any key to continue>
#
# What's your first play call, coach?
#
# Press 1 for a deep center pass.
# Press 2 for a quaterback draw.
# Press 3 for a screen right to halfback
# Press 4 for a curl left to wide receiver
# > curl
#
# Great call, coach. Wisely, your WR runs out of bounds to stop the clock.
#
# You're on the Steelers' 43 yard line with 42 secs left on the clock.
#
# <Press any key to continue>
#
# ...

# %%
# Out:
# 3
